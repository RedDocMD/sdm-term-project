# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
times = [
    72.842174165, 0.700300363, 0.830825425, 0.761379551, 0.771256173, 
    0.804541303, 0.791547605, 0.748225153, 0.766790683, 0.762518598, 
    0.758101934, 0.754022403, 0.697986294, 0.764380744, 0.782581502,
    0.757079155, 0.818374882, 0.822299614, 0.783974708, 0.760358751, 
    0.757844092, 0.75546624, 0.754860544, 0.759693787, 0.776895508, 
    0.77735941, 0.768758699, 0.78123338, 0.761740205, 0.76384916, 
    0.796430731, 0.82277923, 0.765031154, 0.770765535, 0.787606374, 
    0.838337964, 0.811878281, 0.7917733, 0.815414275, 0.800316148, 
    0.770684649, 0.80913716, 0.778574545, 0.78438944, 0.777253905, 
    0.789338236, 0.784017556, 0.785735938, 0.769249121, 0.774811711
]

# %%
fig, ax = plt.subplots()

x = np.arange(len(times))
ax.plot(x, times, marker='o')
ax.set_xlabel('Epoch')
ax.set_ylabel('Time (s)')
ax.set_yscale('log')
ax.set_title('Time taken per Epoch')
ax.set_xticks([5, 15, 25, 35, 45], minor=True)
ax.grid(True, which='major')
ax.grid(True, which='minor', linestyle='-.')

# %%
fig.savefig('plots/perf_epoch.eps')
